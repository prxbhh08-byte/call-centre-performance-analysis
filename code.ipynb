# %%
import pandas as pd

# %%
a = pd.read_csv("Call centre Dashboard.csv")
a
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 0        el-Pa  08-03-2024          Michael            Page    Michael Page
# 1        ah-Ha  11-07-2024           Elijah         Hawkins  Elijah Hawkins
# 2        ia-Ly  14-04-2024           Olivia           Lyons    Olivia Lyons
# 3        ew-Cl  09-12-2024             Drew            Clay       Drew Clay
# 4        va-Sa  17-11-2024              Ava        Sandoval    Ava Sandoval
# ...        ...         ...              ...             ...             ...
# 100136   ew-Cl  18-11-2024             Drew            Clay       Drew Clay
# 100137   ew-Cl  18-12-2024             Drew            Clay       Drew Clay
# 100138   ia-Ly  24-03-2024           Olivia           Lyons    Olivia Lyons
# 100139   ay-Ma  19-08-2024              Ray           Mason       Ray Mason
# 100140   ah-Wa  23-04-2024            Sarah          Walter    Sarah Walter
#
# ...

# %%
a.head(10)
# Out:
#   Call_ID        Date Agent_First_Name Agent_Last_Name   Agent Full Name  \
# 0   el-Pa  08-03-2024          Michael            Page      Michael Page
# 1   ah-Ha  11-07-2024           Elijah         Hawkins    Elijah Hawkins
# 2   ia-Ly  14-04-2024           Olivia           Lyons      Olivia Lyons
# 3   ew-Cl  09-12-2024             Drew            Clay         Drew Clay
# 4   va-Sa  17-11-2024              Ava        Sandoval      Ava Sandoval
# 5   va-Sa  09-12-2024              Ava        Sandoval      Ava Sandoval
# 6   ue-La  14-04-2024          Monique        Lawrence  Monique Lawrence
# 7   ay-Ma  25-11-2024              Ray           Mason         Ray Mason
# 8   ue-La  21-10-2024          Monique        Lawrence  Monique Lawrence
# 9   va-Sa  16-02-2024              Ava        Sandoval      Ava Sandoval
#
#    Agent_Rating Product_Discussed  Call_Duration_Minutes Call_Outcome  \
# 0           5.0             Loans                  10.00      Success
# ...

# %%
a.tail()
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 100136   ew-Cl  18-11-2024             Drew            Clay       Drew Clay
# 100137   ew-Cl  18-12-2024             Drew            Clay       Drew Clay
# 100138   ia-Ly  24-03-2024           Olivia           Lyons    Olivia Lyons
# 100139   ay-Ma  19-08-2024              Ray           Mason       Ray Mason
# 100140   ah-Wa  23-04-2024            Sarah          Walter    Sarah Walter
#
#         Agent_Rating Product_Discussed  Call_Duration_Minutes Call_Outcome  \
# 100136           5.0  Internet Package                  17.41      Failure
# 100137           NaN               NaN                    NaN    Abandoned
# 100138           4.9             Loans                   3.68      Success
# 100139           5.0             Loans                   2.00      Failure
# 100140           4.8             Loans                  22.85      Failure
#
# ...

# %%
a.shape
# Out:
# (100141, 18)

# %%
a.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100141 entries, 0 to 100140
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Call_ID                  100141 non-null  str
#  1   Date                     100141 non-null  str
#  2   Agent_First_Name         100141 non-null  str
#  3   Agent_Last_Name          100141 non-null  str
#  4   Agent Full Name          100141 non-null  str
#  5   Agent_Rating             77683 non-null   float64
#  6   Product_Discussed        77683 non-null   str
#  7   Call_Duration_Minutes    77683 non-null   float64
#  8   Call_Outcome             100141 non-null  str
#  9   Customer_Age             100141 non-null  int64
#  10  Callers_Name             100141 non-null  str
#  11  Customer_Gender          100141 non-null  str
#  12  State                    100141 non-null  str
#  13  Customer_Income_Bracket  100141 non-null  str
# ...

# %%
a.info()
a.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100141 entries, 0 to 100140
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Call_ID                  100141 non-null  str
#  1   Date                     100141 non-null  str
#  2   Agent_First_Name         100141 non-null  str
#  3   Agent_Last_Name          100141 non-null  str
#  4   Agent Full Name          100141 non-null  str
#  5   Agent_Rating             77683 non-null   float64
#  6   Product_Discussed        77683 non-null   str
#  7   Call_Duration_Minutes    77683 non-null   float64
#  8   Call_Outcome             100141 non-null  str
#  9   Customer_Age             100141 non-null  int64
#  10  Callers_Name             100141 non-null  str
#  11  Customer_Gender          100141 non-null  str
#  12  State                    100141 non-null  str
#  13  Customer_Income_Bracket  100141 non-null  str
# ...

# %%
a["Call_Outcome"].unique()
# Out:
# <StringArray>
# ['Success', 'Failure', 'Abandoned']
# Length: 3, dtype: str

# %%
a['Agent Full Name'].nunique()
# Out:
# 13

# %%
a.Product_Discussed.value_counts()
# Out:
# Product_Discussed
# Loans               25404
# Internet Package    24791
# Electronics         12851
# Travel Package      10848
# Insurance            3789
# Name: count, dtype: int64

# %%
a.isna().sum()
# Out:
# Call_ID                        0
# Date                           0
# Agent_First_Name               0
# Agent_Last_Name                0
# Agent Full Name                0
# Agent_Rating               22458
# Product_Discussed          22458
# Call_Duration_Minutes      22458
# Call_Outcome                   0
# Customer_Age                   0
# Callers_Name                   0
# Customer_Gender                0
# State                          0
# Customer_Income_Bracket        0
# Time_of_Day                    0
# Follow_Up_Call_Required        0
# Repeat_Customer                0
# Reason_Call_Abandoned      41717
# dtype: int64

# %%
a.isna().sum() * 100 / len(a)
# Out:
# Call_ID                     0.000000
# Date                        0.000000
# Agent_First_Name            0.000000
# Agent_Last_Name             0.000000
# Agent Full Name             0.000000
# Agent_Rating               22.426379
# Product_Discussed          22.426379
# Call_Duration_Minutes      22.426379
# Call_Outcome                0.000000
# Customer_Age                0.000000
# Callers_Name                0.000000
# Customer_Gender             0.000000
# State                       0.000000
# Customer_Income_Bracket     0.000000
# Time_of_Day                 0.000000
# Follow_Up_Call_Required     0.000000
# Repeat_Customer             0.000000
# Reason_Call_Abandoned      41.658262
# dtype: float64

# %%
a.isna().sum().head
# Out:
# <bound method NDFrame.head of Call_ID                        0
# Date                           0
# Agent_First_Name               0
# Agent_Last_Name                0
# Agent Full Name                0
# Agent_Rating               22458
# Product_Discussed          22458
# Call_Duration_Minutes      22458
# Call_Outcome                   0
# Customer_Age                   0
# Callers_Name                   0
# Customer_Gender                0
# State                          0
# Customer_Income_Bracket        0
# Time_of_Day                    0
# Follow_Up_Call_Required        0
# Repeat_Customer                0
# Reason_Call_Abandoned      41717
# dtype: int64>

# %%
a.isna().sum().idxmax()
# Out:
# 'Reason_Call_Abandoned'

# %%
resolved_calls = a[a['Call_Outcome'] == 'Resolved']
resolved_calls.shape
# Out:
# (0, 18)

# %%
call_duration = a[a["Call_Duration_Minutes"] < 30]
call_duration
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 0        el-Pa  08-03-2024          Michael            Page    Michael Page
# 1        ah-Ha  11-07-2024           Elijah         Hawkins  Elijah Hawkins
# 2        ia-Ly  14-04-2024           Olivia           Lyons    Olivia Lyons
# 3        ew-Cl  09-12-2024             Drew            Clay       Drew Clay
# 4        va-Sa  17-11-2024              Ava        Sandoval    Ava Sandoval
# ...        ...         ...              ...             ...             ...
# 100135   ah-Ha  16-03-2024           Elijah         Hawkins  Elijah Hawkins
# 100136   ew-Cl  18-11-2024             Drew            Clay       Drew Clay
# 100138   ia-Ly  24-03-2024           Olivia           Lyons    Olivia Lyons
# 100139   ay-Ma  19-08-2024              Ray           Mason       Ray Mason
# 100140   ah-Wa  23-04-2024            Sarah          Walter    Sarah Walter
#
# ...

# %%
cmbc = a[a["Customer_Age"].between(25, 35)]
cmbc
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name   Agent Full Name  \
# 0        el-Pa  08-03-2024          Michael            Page      Michael Page
# 4        va-Sa  17-11-2024              Ava        Sandoval      Ava Sandoval
# 6        ue-La  14-04-2024          Monique        Lawrence  Monique Lawrence
# 10       ah-Ha  09-05-2024           Elijah         Hawkins    Elijah Hawkins
# 11       ia-Ly  26-06-2024           Olivia           Lyons      Olivia Lyons
# ...        ...         ...              ...             ...               ...
# 100126   ay-Ma  11-01-2024              Ray           Mason         Ray Mason
# 100129   ia-De  15-07-2024           Sophia        Delacruz   Sophia Delacruz
# 100130   ah-Ha  18-12-2024           Elijah         Hawkins    Elijah Hawkins
# 100133   ew-Cl  24-12-2024             Drew            Clay         Drew Clay
# 100140   ah-Wa  23-04-2024            Sarah          Walter      Sarah Walter
#
# ...

# %%
filtercall= a[a["Follow_Up_Call_Required"] == 'Yes']
filtercall
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name   Agent Full Name  \
# 0        el-Pa  08-03-2024          Michael            Page      Michael Page
# 4        va-Sa  17-11-2024              Ava        Sandoval      Ava Sandoval
# 6        ue-La  14-04-2024          Monique        Lawrence  Monique Lawrence
# 10       ah-Ha  09-05-2024           Elijah         Hawkins    Elijah Hawkins
# 11       ia-Ly  26-06-2024           Olivia           Lyons      Olivia Lyons
# ...        ...         ...              ...             ...               ...
# 100135   ah-Ha  16-03-2024           Elijah         Hawkins    Elijah Hawkins
# 100136   ew-Cl  18-11-2024             Drew            Clay         Drew Clay
# 100137   ew-Cl  18-12-2024             Drew            Clay         Drew Clay
# 100139   ay-Ma  19-08-2024              Ray           Mason         Ray Mason
# 100140   ah-Wa  23-04-2024            Sarah          Walter      Sarah Walter
#
# ...

# %%
resolved_calls = a[(a['Call_Outcome'] == 'Resolved') & (a['Call_Duration_Minutes'] < 15)]
resolved_calls.shape
# Out:
# (0, 18)

# %%
female_ca_repeat = a[(a["Customer_Gender"] == "Female") & (a["State"] == "California") & (a["Repeat_Customer"] == "Yes")]
female_ca_repeat
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 26       va-Sa  17-02-2024              Ava        Sandoval    Ava Sandoval
# 104      ia-Ly  03-10-2024           Olivia           Lyons    Olivia Lyons
# 146      ew-Cl  30-08-2024             Drew            Clay       Drew Clay
# 164      ah-Ha  16-08-2024           Elijah         Hawkins  Elijah Hawkins
# 174      ay-Ma  22-01-2024              Ray           Mason       Ray Mason
# ...        ...         ...              ...             ...             ...
# 99789    va-Sa  19-01-2024              Ava        Sandoval    Ava Sandoval
# 99808    va-Sa  03-07-2024              Ava        Sandoval    Ava Sandoval
# 99993    va-Sa  15-03-2024              Ava        Sandoval    Ava Sandoval
# 100017   ay-Ma  02-12-2024              Ray           Mason       Ray Mason
# 100122   ew-Cl  07-05-2024             Drew            Clay       Drew Clay
#
# ...

# %%
filter_agent = a[(a["Agent_Rating"] >= 4.5) & (a["Call_Duration_Minutes"] < 5)]
filter_agent
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 4        va-Sa  17-11-2024              Ava        Sandoval    Ava Sandoval
# 10       ah-Ha  09-05-2024           Elijah         Hawkins  Elijah Hawkins
# 21       va-Sa  11-08-2024              Ava        Sandoval    Ava Sandoval
# 23       ia-Ly  21-11-2024           Olivia           Lyons    Olivia Lyons
# 38       va-Sa  05-02-2024              Ava        Sandoval    Ava Sandoval
# ...        ...         ...              ...             ...             ...
# 100114   ew-Cl  07-06-2024             Drew            Clay       Drew Clay
# 100115   ah-Ha  03-07-2024           Elijah         Hawkins  Elijah Hawkins
# 100130   ah-Ha  18-12-2024           Elijah         Hawkins  Elijah Hawkins
# 100138   ia-Ly  24-03-2024           Olivia           Lyons    Olivia Lyons
# 100139   ay-Ma  19-08-2024              Ray           Mason       Ray Mason
#
# ...

# %%
abandoned = a[a["Reason_Call_Abandoned"].notna()]
abandoned
# Out:
#        Call_ID        Date Agent_First_Name Agent_Last_Name Agent Full Name  \
# 1        ah-Ha  11-07-2024           Elijah         Hawkins  Elijah Hawkins
# 3        ew-Cl  09-12-2024             Drew            Clay       Drew Clay
# 4        va-Sa  17-11-2024              Ava        Sandoval    Ava Sandoval
# 5        va-Sa  09-12-2024              Ava        Sandoval    Ava Sandoval
# 7        ay-Ma  25-11-2024              Ray           Mason       Ray Mason
# ...        ...         ...              ...             ...             ...
# 100130   ah-Ha  18-12-2024           Elijah         Hawkins  Elijah Hawkins
# 100136   ew-Cl  18-11-2024             Drew            Clay       Drew Clay
# 100137   ew-Cl  18-12-2024             Drew            Clay       Drew Clay
# 100139   ay-Ma  19-08-2024              Ray           Mason       Ray Mason
# 100140   ah-Wa  23-04-2024            Sarah          Walter    Sarah Walter
#
# ...

# %%
# use the actual column name with spaces
select_col = a[["Agent Full Name", "Call_Duration_Minutes", "Customer_Age"]]
select_col
# Out:
#        Agent Full Name  Call_Duration_Minutes  Customer_Age
# 0         Michael Page                  10.00            25
# 1       Elijah Hawkins                  26.22            20
# 2         Olivia Lyons                  10.00            40
# 3            Drew Clay                   2.00            20
# 4         Ava Sandoval                   2.00            35
# ...                ...                    ...           ...
# 100136       Drew Clay                  17.41            20
# 100137       Drew Clay                    NaN            45
# 100138    Olivia Lyons                   3.68            20
# 100139       Ray Mason                   2.00            50
# 100140    Sarah Walter                  22.85            25
#
# [100141 rows x 3 columns]

# %%
a.groupby("Call_Outcome")["Call_Duration_Minutes"].mean()
# Out:
# Call_Outcome
# Abandoned          NaN
# Failure      15.485305
# Success      16.905414
# Name: Call_Duration_Minutes, dtype: float64

# %%
a["Agent Full Name"].value_counts()
# Out:
# Agent Full Name
# Ava Sandoval        19981
# Elijah Hawkins      16024
# Drew Clay           13923
# Ray Mason           10291
# Olivia Lyons         8929
# Monique Lawrence     7964
# Michael Page         5997
# Liam Martinez        4968
# Zoe Newman           3987
# Sophia Delacruz      3054
# Sarah Walter         2043
# Katrina Williams     1975
# Samuel Smith         1005
# Name: count, dtype: int64

# %%
a["State"].value_counts()
# Out:
# State
# New York          16064
# California        12067
# North Carolina    11840
# Nevada            10044
# Texas              8123
# Colorado           8017
# Arizona            6068
# Georgia            5151
# Washington         4962
# Florida            4058
# Alabama            2885
# Oregon             2004
# Michigan           1909
# Virginia           1012
# Kentucky           1004
# Ohio                995
# Maryland            993
# Illinois            993
# Pennsylvania        990
# Massachusetts       962
# Name: count, dtype: int64

# %%
a.groupby("Customer_Age")["Time_of_Day"].value_counts()
# Out:
# Customer_Age  Time_of_Day
# 14            Afternoon         2
# 15            Afternoon      6898
#               Morning        5756
#               Evening        1835
# 16            Afternoon      7027
#                              ...
# 65            Morning           1
#               Afternoon         1
# 66            Morning           1
# 68            Morning           1
# 69            Afternoon         1
# Name: count, Length: 93, dtype: int64

# %%
A_s = a.groupby("Agent Full Name").agg(
    total_calls=("Call_ID", "count"),
    average_rating=("Agent_Rating", "mean"),
    average_call_duration=("Call_Duration_Minutes", "mean")
)

A_s
# Out:
#                   total_calls  average_rating  average_call_duration
# Agent Full Name
# Ava Sandoval            19981        4.129452              18.339313
# Drew Clay               13923        4.137774              14.937136
# Elijah Hawkins          16024        4.120637              14.695539
# Katrina Williams         1975        4.100749              19.443193
# Liam Martinez            4968        4.146309              15.778396
# Michael Page             5997        4.137048              19.424595
# Monique Lawrence         7964        4.124592              15.408958
# Olivia Lyons             8929        4.149776              16.002319
# Ray Mason               10291        4.137026              14.740502
# Samuel Smith             1005        4.109034              15.761693
# Sarah Walter             2043        4.161212              15.088691
# Sophia Delacruz          3054        4.063551              18.217839
# ...

# %%
Agent_name_rating = a.groupby("Agent Full Name")["Agent_Rating"].mean().sort_values(ascending=False).head(10)

Agent_name_rating
# Out:
# Agent Full Name
# Sarah Walter        4.161212
# Olivia Lyons        4.149776
# Liam Martinez       4.146309
# Drew Clay           4.137774
# Michael Page        4.137048
# Ray Mason           4.137026
# Ava Sandoval        4.129452
# Monique Lawrence    4.124592
# Zoe Newman          4.122085
# Elijah Hawkins      4.120637
# Name: Agent_Rating, dtype: float64
